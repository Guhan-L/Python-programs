# %%
def pc(n):
    for i in range(2,int(n**.5)+1):
        if n%i==0:
            print("Not a prime")
            break
        else:
            print("Prime")
            break
num=int(input("Enter a number:"))
pc(num)
# Out:
# Enter a number: 11
# Prime

# %%
def isprime(n):
    for i in range(2,int(n**.5)+1):
        if n%i==0:
           return False
           
        else:
            return True
         
num=int(input("Enter a number:"))
isprime(num)
# Out:
# Enter a number: 12
# False

# %%
def isprime(n):
    for i in range(2,int(n**.5)+1):
        if n%i==0:
           return False
           
        else:
            return True
         
l=[66,97,19,32]
for n in l:
    if isprime(n):
        print(n)
# Out:
# 97
# 19
